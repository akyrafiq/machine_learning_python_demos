# %% [markdown]
# # 7CCMFM18 Machine Learning
# King's College London <br>
# Academic year 2023-2024 <br>
# Lecturer: Mario Martone
# Tutor: Akmal Rafiq

# %% [markdown]
# Version Date: <i>8th April 2023</i>

# %% [markdown]
# You will need to install:
#
# 1. SentenceTransformer.
# 2. NLTK
# 3. Sklearn
# 4. english-words

# %%
# !pip install sentence_transformers sklearn english_words

# %% [markdown]
# First let's load in a few libraries:

# %%
import scipy.sparse.linalg
import sklearn
from sklearn.metrics import pairwise_distances

# %% [markdown]
# ## NLP: sentence transformer

# %% [markdown]
# Then load our model (you can try comparing different models!):

# %%
from sentence_transformers import SentenceTransformer
model_name = 'all-distilroberta-v1'
model = SentenceTransformer(model_name)

# %% [markdown]
# You can find a list of pre-trained modeels here: https://www.sbert.net/docs/pretrained_models.html

# %% [markdown]
# Now let's embed two simple sentences:

# %%
sent1=model.encode('Mario studies hard')
sent2=model.encode('Mario goes to school')

# %% [markdown]
# **Cosine Similarity** is a measure used to gauge how similar two vectors are, irrespective of their size. Mathematically, it calculates the cosine of the angle between two vectors projected in a multi-dimensional space. This metric is widely used in various fields, including data analysis, natural language processing, and machine learning, particularly in systems involving text comparison.
#
# The cosine similarity between two vectors is calculated by taking the dot product of the vectors and then dividing that by the product of the magnitudes (or lengths) of the vectors.
#
# $$cos(θ) = \frac{A \cdot B}{||A||  ||B||}$$
#
# This results in a value between -1 and 1, where 1 indicates that the vectors are identical, 0 indicates that the vectors are orthogonal (or have no similarity), and -1 indicates that the vectors are diametrically opposed.
#
# In the context of text analysis, vectors often represent word counts or tf-idf scores (which reflect how important a word is within a document in a collection of documents). By calculating the cosine similarity between these vectors, it's possible to determine how similar the documents are in terms of their content.
#
# Let's compute the similarity score:

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sklearn.metrics.pairwise.cosine_similarity([sent1,sent2])
# Out:
# array([[1.        , 0.76597095],
#        [0.76597095, 0.99999994]], dtype=float32)

# %% [markdown]
# The off-diagonal terms are the one that matter and they are indeed close to 1! Now let's try to see what happens with a sentence which has a different meaning:

# %%
sent3=model.encode('Tomorrow the sky will be blue')
sklearn.metrics.pairwise.cosine_similarity([sent1,sent2,sent3])
# Out:
# array([[1.        , 0.76597095, 0.0752472 ],
#        [0.76597095, 0.99999994, 0.14101554],
#        [0.0752472 , 0.14101554, 0.99999976]], dtype=float32)

# %% [markdown]
# And you can see that the similarity of sentence 3 with sentence 1 and 2 is far smaller.

# %% [markdown]
# ### Look for similarities:

# %% [markdown]
# Now let's play with the large English vocabulary - we shall grab a sample list from the english_words packagee

# %%
from english_words import english_words_alpha_set

# %%
len(list(english_words_alpha_set))
# Out:
# 25474

# %%
list(english_words_alpha_set)[:10]
# Out:
# ['gneiss',
#  'Dobbs',
#  'boil',
#  'dogwood',
#  'Ainu',
#  'parsimonious',
#  'Coriolanus',
#  'jenny',
#  'Sicily',
#  'gravid']

# %% [markdown]
# And let's check the words that have the highest similarity with the word football:

# %%
similarity={}
encode_football=model.encode('football')

for word in list(english_words_alpha_set):
    word_encode=model.encode(word)
    similarity[word]=sklearn.metrics.pairwise.cosine_similarity([encode_football,word_encode])[0,1]

# %% [markdown]
# And now let's check the words that are the most similar with football:

# %%
sorted(similarity.items(), key=lambda item: item[1],reverse=True)
# Out:
# [('football', 0.99999976),
#  ('soccer', 0.86900795),
#  ('basketball', 0.81611115),
#  ('sport', 0.70091105),
#  ('hockey', 0.6746446),
#  ('cricket', 0.67358565),
#  ('baseball', 0.670014),
#  ('volleyball', 0.6460309),
#  ('softball', 0.6318909),
#  ('sportswriting', 0.6087425),
#  ('ball', 0.60338104),
#  ('volley', 0.58906734),
#  ('tennis', 0.5827517),
#  ('lacrosse', 0.5714959),
#  ('athlete', 0.57062495),
#  ('golf', 0.5705202),
#  ('chess', 0.5621939),
#  ('athletic', 0.55184615),
#  ('snowball', 0.5504932),
#  ('sportsmen', 0.54786897),
#  ('badminton', 0.54423267),
#  ('ballet', 0.5431351),
#  ('pong', 0.5393827),
#  ('madden', 0.5365356),
#  ('knuckleball', 0.53595364),
#  ('polo', 0.52711654),
#  ('jockey', 0.5201056),
#  ('sporty', 0.5108114),
#  ('television', 0.50035995),
#  ('karate', 0.499893),
#  ('sportswriter', 0.4973939),
#  ('skate', 0.4969545),
#  ('quarterback', 0.49339512),
#  ('sportsman', 0.49299866),
#  ('touchdown', 0.4866844),
#  ('Olympic', 0.4849062),
#  ('sadden', 0.48392475),
#  ('hooligan', 0.48306835),
#  ('wrestle', 0.48156458),
#  ('pinball', 0.47711605),
#  ('ballfield', 0.47590226),
#  ('school', 0.4722568),
#  ('punt', 0.47151828),
#  ('fogging', 0.4699993),
#  ('footwear', 0.46863303),
#  ('college', 0.4657049),
#  ('archery', 0.4627897),
#  ('screwball', 0.4551698),
#  ('hogging', 0.45411265),
#  ('stadium', 0.4538225),
#  ('combat', 0.4532857),
#  ('butterball', 0.45209593),
#  ('refereeing', 0.45106107),
#  ('yardage', 0.44971105),
#  ('lascar', 0.44899976),
#  ('footwork', 0.4486404),
#  ('pastime', 0.4477477),
#  ('martial', 0.44689095),
#  ('tackle', 0.44675243),
#  ('trestle', 0.4462271),
#  ('TV', 0.44612128),
#  ('linebacker', 0.44365364),
#  ('sex', 0.44180596),
#  ('sling', 0.4415658),
#  ('gamble', 0.4394375),
#  ('academia', 0.43898153),
#  ('fantasy', 0.43716335),
#  ('gridiron', 0.4360906),
#  ('gunsling', 0.4360792),
#  ('curricular', 0.43585718),
#  ('swordplay', 0.43408924),
#  ('cannonball', 0.43373373),
#  ('flogging', 0.43367004),
#  ('beer', 0.4321171),
#  ('bowl', 0.43198115),
#  ('skirt', 0.4312857),
#  ('league', 0.43127504),
#  ('brawl', 0.43038636),
#  ('jogging', 0.42968613),
#  ('highball', 0.42903557),
#  ('field', 0.42812002),
#  ('gladden', 0.42133725),
#  ('career', 0.41967088),
#  ('pornography', 0.41830856),
#  ('sportswear', 0.4176355),
#  ('country', 0.4173192),
#  ('fashion', 0.41641623),
#  ('babysitting', 0.41628334),
#  ('teammate', 0.4160849),
#  ('footfall', 0.41527548),
#  ('duchess', 0.41511446),
#  ('musculature', 0.4147553),
#  ('kickoff', 0.41198605),
#  ('skat', 0.41015744),
#  ('homework', 0.41012055),
#  ('bunt', 0.40981066),
#  ('agricultural', 0.4088081),
#  ('fowl', 0.40741467),
#  ('Soc', 0.40559182),
#  ('photography', 0.4031812),
#  ('fumble', 0.40291083),
#  ('yardstick', 0.40221372),
#  ('blackball', 0.4001849),
#  ('varsity', 0.39913154),
#  ('politico', 0.3987592),
#  ('squatting', 0.39779758),
#  ('religion', 0.39774433),
#  ('comport', 0.39768767),
#  ('science', 0.39716947),
#  ('alcohol', 0.39693403),
#  ('skateboard', 0.3967318),
#  ('politicking', 0.3965417),
#  ('war', 0.3959714),
#  ('music', 0.39541462),
#  ('marijuana', 0.39535064),
#  ('footstool', 0.3952595),
#  ('togging', 0.39492935),
#  ('puck', 0.39477903),
#  ('Hollywood', 0.3947177),
#  ('bootlegging', 0.39468604),
#  ('bogging', 0.39398444),
#  ('turf', 0.3933472),
#  ('biology', 0.39286083),
#  ('squat', 0.3921352),
#  ('Boeing', 0.39203656),
#  ('slam', 0.39095378),
#  ('foundling', 0.39065686),
#  ('befogging', 0.38991827),
#  ('marathon', 0.38954538),
#  ('English', 0.38898462),
#  ('tobacco', 0.38877967),
#  ('horseplay', 0.38873458),
#  ('tech', 0.38869625),
#  ('drug', 0.38824055),
#  ('pitch', 0.38785514),
#  ('gymnastic', 0.38713747),
#  ('squash', 0.38684392),
#  ('forage', 0.38599378),
#  ('curriculum', 0.38478875),
#  ('chef', 0.38474447),
#  ('decathlon', 0.3845883),
#  ('skater', 0.38445497),
#  ('kidnapping', 0.38389432),
#  ('fullback', 0.3834045),
#  ('fraternity', 0.3821054),
#  ('calf', 0.38193107),
#  ('railroad', 0.3812626),
#  ('compete', 0.38052815),
#  ('franchise', 0.3803172),
#  ('familism', 0.38029957),
#  ('hairspring', 0.37997884),
#  ('colleague', 0.3789637),
#  ('wingback', 0.3784879),
#  ('physic', 0.37758356),
#  ('glee', 0.37682393),
#  ('extracurricular', 0.3764667),
#  ('underling', 0.37638253),
#  ('Societe', 0.37571222),
#  ('NCAA', 0.37567717),
#  ('feminism', 0.37566242),
#  ('financial', 0.37545788),
#  ('frolicking', 0.37532932),
#  ('military', 0.37512115),
#  ('bodybuilding', 0.37507865),
#  ('track', 0.37433428),
#  ('mobility', 0.37417167),
#  ('kick', 0.37414026),
#  ('talisman', 0.37318212),
#  ('furlong', 0.3731413),
#  ('game', 0.3730902),
#  ('jury', 0.3730132),
#  ('yard', 0.37300622),
#  ('squad', 0.3729027),
#  ('heroism', 0.37279105),
#  ('habitation', 0.3727088),
#  ('strafe', 0.372226),
#  ('bedlam', 0.37187907),
#  ('putt', 0.37167704),
#  ('linemen', 0.37153018),
#  ('scrabble', 0.37117535),
#  ('muscle', 0.37106818),
#  ('schoolteacher', 0.37104678),
#  ('rock', 0.370964),
#  ('sociology', 0.37094393),
#  ('tendon', 0.37002006),
#  ('business', 0.36994284),
#  ('furniture', 0.36949652),
#  ('teenage', 0.36924902),
#  ('gun', 0.36888552),
#  ('coltsfoot', 0.36861053),
#  ('butchery', 0.36830056),
#  ('politician', 0.368267),
#  ('Bowdoin', 0.3676219),
#  ('swank', 0.36743897),
#  ('philology', 0.36731404),
#  ('barbecue', 0.3672933),
#  ('jewelry', 0.36715055),
#  ('grocery', 0.3669957),
#  ('literature', 0.36636418),
#  ('earthmoving', 0.36541697),
#  ('commerce', 0.3651374),
#  ('foot', 0.36494327),
#  ('dogging', 0.36490262),
#  ('leisure', 0.36463615),
#  ('blackjack', 0.36460042),
#  ('crime', 0.36412495),
#  ('fling', 0.36389333),
#  ('cannabis', 0.36362916),
#  ('bodybuilder', 0.36276603),
#  ('farm', 0.36271375),
#  ('percussion', 0.36264163),
#  ('stunt', 0.36240268),
#  ('spun', 0.3622077),
#  ('rabble', 0.36219585),
#  ('casework', 0.36128423),
#  ('homecoming', 0.36106867),
#  ('playtime', 0.36097926),
#  ('coach', 0.3608969),
#  ('radio', 0.36008734),
#  ('swim', 0.35995317),
#  ('hamlet', 0.35993278),
#  ('socioeconomic', 0.35912758),
#  ('rape', 0.35903057),
#  ('dutchess', 0.35901457),
#  ('physiology', 0.3589626),
#  ('nautical', 0.3588922),
#  ('trafficking', 0.35880378),
#  ('jazz', 0.35865885),
#  ('banjo', 0.35839885),
#  ('cinema', 0.35781354),
#  ('jumble', 0.3574345),
#  ('forestry', 0.3570145),
#  ('agriculture', 0.35693556),
#  ('cheerleader', 0.3569051),
#  ('panicking', 0.35676956),
#  ('lifestyle', 0.35658234),
#  ('fieldwork', 0.35655117),
#  ('cowboy', 0.35651004),
#  ('prostitution', 0.35647184),
#  ('physician', 0.3564508),
#  ('schoolwork', 0.35622495),
#  ('play', 0.35618454),
#  ('fiesta', 0.35605305),
#  ('England', 0.3552075),
#  ('battle', 0.35503477),
#  ('playboy', 0.3546263),
#  ('presidential', 0.35361362),
#  ('craft', 0.35353518),
#  ('knee', 0.35334617),
#  ('airlift', 0.35270518),
#  ('naval', 0.35264957),
#  ('bakery', 0.35264266),
#  ('liturgy', 0.35236108),
#  ('army', 0.35220325),
#  ('flag', 0.3521887),
#  ('defensive', 0.35187232),
#  ('melee', 0.35171425),
#  ('celebrity', 0.35167557),
#  ('Englishmen', 0.3516507),
#  ('season', 0.35164055),
#  ('footman', 0.35105127),
#  ('playoff', 0.3509105),
#  ('meteorology', 0.3508734),
#  ('siesta', 0.35084957),
#  ('finance', 0.3508266),
#  ('battlefield', 0.3497735),
#  ('auburn', 0.3496244),
#  ('cowl', 0.3495823),
#  ('admission', 0.34954175),
#  ('schoolroom', 0.34940627),
#  ('tournament', 0.34908524),
#  ('puffball', 0.34886414),
#  ('patriot', 0.3485374),
#  ('cornfield', 0.348435),
#  ('psychology', 0.34819102),
#  ('freshmen', 0.34814787),
#  ('squabble', 0.34799087),
#  ('plaything', 0.3479628),
#  ('bay', 0.3477192),
#  ('talismanic', 0.34769484),
#  ('bicker', 0.3476798),
#  ('earth', 0.34751153),
#  ('hobby', 0.34651545),
#  ('cowslip', 0.34650108),
#  ('warehouse', 0.34633455),
#  ('gym', 0.34629256),
#  ('goal', 0.34619588),
#  ('health', 0.3461225),
#  ('collegiate', 0.3458588),
#  ('housewives', 0.3456872),
#  ('bolster', 0.34556842),
#  ('fingernail', 0.34539893),
#  ('energy', 0.34525037),
#  ('history', 0.34501565),
#  ('bike', 0.34490842),
#  ('slugging', 0.34435445),
#  ('Brazil', 0.34425333),
#  ('cuisine', 0.34382683),
#  ('Viking', 0.34366596),
#  ('rickets', 0.34332445),
#  ('garage', 0.34327477),
#  ('brewery', 0.34310192),
#  ('surgeon', 0.34277752),
#  ('physique', 0.34273875),
#  ('waterfowl', 0.3425286),
#  ('machismo', 0.34237626),
#  ('politic', 0.34215015),
#  ('backgammon', 0.34203017),
#  ('Foote', 0.34155256),
#  ('fife', 0.3413871),
#  ('travel', 0.34124625),
#  ('conference', 0.34092623),
#  ('frail', 0.34055966),
#  ('lifelong', 0.340547),
#  ('handicapping', 0.34042907),
#  ('sabbath', 0.34019017),
#  ('stumble', 0.3399979),
#  ('underclassmen', 0.33993733),
#  ('holiday', 0.3398845),
#  ('poultry', 0.33977616),
#  ('hatchery', 0.33977336),
#  ('backyard', 0.33955792),
#  ('food', 0.3394608),
#  ('firework', 0.33937323),
#  ('physiotherapy', 0.33935294),
#  ('heroin', 0.33916867),
#  ('toss', 0.3389794),
#  ('battleground', 0.33867013),
#  ('finessing', 0.3385285),
#  ('ethnology', 0.3380683),
#  ('chemistry', 0.3378901),
#  ('warmup', 0.3378036),
#  ('buffalo', 0.3376534),
#  ('featherbedding', 0.33758217),
#  ('language', 0.33758205),
#  ('America', 0.3371792),
#  ('flex', 0.33709264),
#  ('horseback', 0.33696622),
#  ('cockfight', 0.33685046),
#  ('artillery', 0.33659756),
#  ('playground', 0.33649808),
#  ('funereal', 0.33636436),
#  ('highfalutin', 0.33611625),
#  ('aircraft', 0.33604747),
#  ('tugging', 0.3358961),
#  ('swigging', 0.33589023),
#  ('schoolboy', 0.33586636),
#  ('pietism', 0.33577296),
#  ('kitchen', 0.33570492),
#  ('elbow', 0.33552274),
#  ('handgun', 0.33550096),
#  ('spacecraft', 0.33549628),
#  ('footpad', 0.3353787),
#  ('freshman', 0.33511135),
#  ('halfback', 0.33501303),
#  ('volcano', 0.33489475),
#  ('maritime', 0.3347686),
#  ('housewife', 0.3347279),
#  ('horticulture', 0.33459634),
#  ('telephony', 0.3345785),
#  ('piano', 0.33451813),
#  ('bulletin', 0.33413178),
#  ('fiefdom', 0.3337952),
#  ('world', 0.33365262),
#  ('seething', 0.33327445),
#  ('cook', 0.33316427),
#  ('peafowl', 0.33300585),
#  ('volcanism', 0.33295062),
#  ('militarism', 0.33280236),
#  ('boxcar', 0.3327803),
#  ('Islam', 0.33271086),
#  ('referee', 0.3326716),
#  ('technology', 0.3326416),
#  ('clogging', 0.3325829),
#  ('filly', 0.33255896),
#  ('team', 0.3324412),
#  ('competitive', 0.33228534),
#  ('balletomane', 0.33227175),
#  ('telegraphy', 0.33221725),
#  ('pacifism', 0.33205706),
#  ('laundry', 0.33197016),
#  ('mutuel', 0.33185536),
#  ('Liverpool', 0.3317989),
#  ('fanfare', 0.33150476),
#  ('fame', 0.33145547),
#  ('nursery', 0.33138448),
#  ('offensive', 0.3313434),
#  ('jargon', 0.3310718),
#  ('festoon', 0.3309967),
#  ('gunfight', 0.3309291),
#  ('fish', 0.3306979),
#  ('institution', 0.33059418),
#  ('religious', 0.33053082),
#  ('airfield', 0.33049363),
#  ('Arianism', 0.33042464),
#  ('bagging', 0.3302432),
#  ('fiction', 0.33007395),
#  ('bridgework', 0.33005112),
#  ('foodstuff', 0.33000293),
#  ('violin', 0.32955962),
#  ('basket', 0.32938236),
#  ('culinary', 0.32916105),
#  ('highroad', 0.3291297),
#  ('emitting', 0.32908),
#  ('tribal', 0.3289431),
#  ('academic', 0.32894203),
#  ('foul', 0.32887536),
#  ('banquet', 0.32871997),
#  ('tuition', 0.32848513),
#  ('clarinet', 0.32839674),
#  ('feud', 0.32819617),
#  ('sightseeing', 0.32816148),
#  ('safety', 0.32812977),
#  ('fortin', 0.32791752),
#  ('coachwork', 0.32787663),
#  ('cling', 0.3278411),
#  ('footage', 0.32736126),
#  ('libido', 0.32712805),
#  ('wine', 0.3270929),
#  ('radiology', 0.3269986),
#  ('monopoly', 0.3265121),
#  ('boycott', 0.32642084),
#  ('swum', 0.3263103),
#  ('handicraft', 0.32613838),
#  ('js', 0.32600206),
#  ('race', 0.32571155),
#  ('alumni', 0.3256697),
#  ('springtime', 0.3255729),
#  ('purl', 0.32541507),
#  ('lawgiving', 0.32538083),
#  ('thunder', 0.32509726),
#  ('broadcast', 0.3250348),
#  ('Britain', 0.32500717),
#  ('USAF', 0.3249688),
#  ('forensic', 0.3249134),
#  ('toilet', 0.32490706),
#  ('sprawl', 0.32468408),
#  ('leg', 0.32459226),
#  ('court', 0.32457888),
#  ('allege', 0.3245117),
#  ('hurdle', 0.3242765),
#  ('smack', 0.32415),
#  ('motorcycle', 0.324017),
#  ('rain', 0.32394257),
#  ('poetry', 0.32393473),
#  ('brothel', 0.3238796),
#  ('churchgoing', 0.32374245),
#  ('industry', 0.32365537),
#  ('hangout', 0.32328892),
#  ('carpetbagging', 0.32321948),
#  ('office', 0.32315648),
#  ('Englishman', 0.322681),
#  ('coeducation', 0.32259005),
#  ('alfalfa', 0.32236543),
#  ('portraiture', 0.32223675),
#  ('literary', 0.32211137),
#  ('apparel', 0.32166725),
#  ('weaponry', 0.321665),
#  ('worship', 0.32163244),
#  ('Egyptology', 0.3213576),
#  ('pizza', 0.3213005),
#  ('bouquet', 0.32128972),
#  ('lightning', 0.32126868),
#  ('wildlife', 0.3212377),
#  ('collage', 0.32110316),
#  ('tumble', 0.32090616),
#  ('telephone', 0.3208235),
#  ('fetish', 0.32079768),
#  ('wire', 0.32078),
#  ('matriculate', 0.32070833),
#  ('sterling', 0.32059073),
#  ('British', 0.32048714),
#  ('anything', 0.32039917),
#  ('batwing', 0.3203311),
#  ('bowstring', 0.32018793),
#  ('programming', 0.32015336),
#  ('playhouse', 0.3200915),
#  ('foxtail', 0.31989503),
#  ('schoolgirl', 0.31964368),
#  ('restaurant', 0.31939703),
#  ('infield', 0.31927243),
#  ('sky', 0.3191061),
#  ('abuse', 0.3189125),
#  ('tingle', 0.3188973),
#  ('sociolinguistic', 0.31874603),
#  ('muscular', 0.31871444),
#  ('philosophy', 0.31863588),
#  ('aerospace', 0.31860185),
#  ('geology', 0.31855106),
#  ('billy', 0.3185386),
#  ('space', 0.3183969),
#  ('heritage', 0.3183908),
#  ('knives', 0.31834406),
#  ('club', 0.31818497),
#  ('conferring', 0.31806254),
#  ('clash', 0.31802267),
#  ('throw', 0.31780565),
#  ('teamster', 0.31780466),
#  ('pigging', 0.31775755),
#  ('psychiatry', 0.3176309),
#  ('church', 0.31755805),
#  ('yoga', 0.31751546),
#  ('Bengal', 0.31744885),
#  ('kindergarten', 0.31728935),
#  ('unity', 0.3172326),
#  ('diplomacy', 0.31717408),
#  ('bribery', 0.31709313),
#  ('turmoil', 0.31701893),
#  ('disciplinary', 0.31696978),
#  ('countrymen', 0.31673282),
#  ('headquarter', 0.3167104),
#  ('flight', 0.31643486),
#  ('hosiery', 0.31623173),
#  ('basketry', 0.31618875),
#  ('media', 0.31609344),
#  ('bicycle', 0.3160876),
#  ('hookup', 0.31594795),
#  ('frock', 0.31590736),
#  ('scholastic', 0.31585974),
#  ('slogging', 0.3158525),
#  ('crouch', 0.31580836),
#  ('gamesmanship', 0.31565264),
#  ('biz', 0.3154071),
#  ('blackboard', 0.31529927),
#  ('genre', 0.31525683),
#  ('Rutgers', 0.31524706),
#  ('entertain', 0.31518346),
#  ('Swahili', 0.31517124),
#  ('Balinese', 0.31509817),
#  ('horse', 0.31504822),
#  ('nature', 0.31490684),
#  ('swing', 0.31486222),
#  ('shoe', 0.31486136),
#  ('flamingo', 0.31464455),
#  ('boredom', 0.3145605),
#  ('hardworking', 0.31429863),
#  ('spin', 0.31426987),
#  ('jigging', 0.31421727),
#  ('cabinetry', 0.31415176),
#  ('buckeye', 0.3139773),
#  ('circa', 0.31377238),
#  ('sanderling', 0.31375194),
#  ('allotting', 0.31355745),
#  ('bath', 0.3134882),
#  ('transportation', 0.31344426),
#  ('sweatshop', 0.31340915),
#  ('cocktail', 0.3133964),
#  ('penalty', 0.313361),
#  ('gimbal', 0.3130658),
#  ('vodka', 0.31303304),
#  ('freedom', 0.31283695),
#  ('thrown', 0.3128321),
#  ('humanitarian', 0.31276074),
#  ('U.S.A', 0.31266087),
#  ('treadmill', 0.31260586),
#  ('rubble', 0.31251076),
#  ('wrest', 0.31240493),
#  ('Tamil', 0.3122884),
#  ('Achilles', 0.31224412),
#  ('practitioner', 0.31210846),
#  ('stoke', 0.31209514),
#  ('soldiery', 0.31200516),
#  ('coke', 0.31196243),
#  ('practise', 0.3118028),
#  ('road', 0.3117954),
#  ('fundraising', 0.3117886),
#  ('foster', 0.31175685),
#  ('dame', 0.31174603),
#  ('wool', 0.3117391),
#  ('hedonism', 0.31173328),
#  ('plugging', 0.31163523),
#  ('port', 0.31153122),
#  ('sexual', 0.31141073),
#  ('UCLA', 0.31134048),
#  ('bowline', 0.3113091),
#  ('bong', 0.31130064),
#  ('airplane', 0.31114095),
#  ('pedagogy', 0.31113547),
#  ('warfare', 0.3109727),
#  ('heroes', 0.3109279),
#  ('shotgun', 0.31089213),
#  ('USC', 0.3108812),
#  ('job', 0.31077945),
#  ('baptism', 0.3107769),
#  ('comedy', 0.31065768),
#  ('bow', 0.31043684),
#  ('profession', 0.31040817),
#  ('writhing', 0.3104026),
#  ('workday', 0.31029722),
#  ('facade', 0.31026083),
#  ('atheism', 0.3102483),
#  ('sorcery', 0.31015968),
#  ('exhibition', 0.31006715),
#  ('animism', 0.31006572),
#  ('cattle', 0.3099171),
#  ('pedal', 0.30988032),
#  ('conferee', 0.30978101),
#  ('pottery', 0.30976748),
#  ('possession', 0.30971172),
#  ('taboo', 0.30966195),
#  ('gosling', 0.30960637),
#  ('memorabilia', 0.30942455),
#  ('exportation', 0.30942357),
#  ('economy', 0.30932572),
#  ('bowel', 0.3092196),
#  ('ferry', 0.30921847),
#  ('schoolhouse', 0.30920047),
#  ('fest', 0.30908158),
#  ('kid', 0.30907798),
#  ('pornographer', 0.30907276),
#  ('trophy', 0.30898735),
#  ('schoolgirlish', 0.30888397),
#  ('rubric', 0.30872595),
#  ('ford', 0.3086154),
#  ('buffet', 0.3086087),
#  ('javelin', 0.3085887),
#  ('prohibition', 0.30852503),
#  ('programmer', 0.3084918),
#  ('fossil', 0.30847037),
#  ('psychotherapy', 0.30835927),
#  ('spinster', 0.30812392),
#  ('cookery', 0.30808902),
#  ('Foss', 0.30799228),
#  ('frolic', 0.30788136),
#  ('bikini', 0.307835),
#  ('hooves', 0.30781987),
#  ('baffle', 0.30780885),
#  ('sweater', 0.30775136),
#  ('inferring', 0.30767104),
#  ('abroad', 0.30763018),
#  ('tussle', 0.30755925),
#  ('cocaine', 0.30754784),
#  ('prison', 0.3075447),
#  ('jilt', 0.30752522),
#  ('fabric', 0.3073216),
#  ('foil', 0.3071844),
#  ('sophomore', 0.30716753),
#  ('foliage', 0.30706567),
#  ('cologne', 0.30698305),
#  ('fiddlestick', 0.30697978),
#  ('babble', 0.30693597),
#  ('steamboat', 0.3067231),
#  ('CUNY', 0.30659416),
#  ('lawyer', 0.30659372),
#  ('street', 0.30656436),
#  ('offspring', 0.306462),
#  ('brig', 0.3064593),
#  ('traffic', 0.30639082),
#  ('footbridge', 0.30633837),
#  ('bespoke', 0.3063118),
#  ('pitfall', 0.30621457),
#  ('boulder', 0.30611628),
#  ('audiovisual', 0.30599046),
#  ('footmen', 0.30579442),
#  ('cardboard', 0.30574983),
#  ('competition', 0.30566144),
#  ('navy', 0.30563653),
#  ('constitution', 0.30561626),
#  ('backboard', 0.30560392),
#  ('memorial', 0.3055627),
#  ('bully', 0.3055197),
#  ('flung', 0.3054303),
#  ('therapist', 0.30540654),
#  ('homicide', 0.30533826),
#  ('bloodletting', 0.3052612),
#  ('jockstrap', 0.30519125),
#  ('royalty', 0.30513516),
#  ('coliseum', 0.3051337),
#  ('metabolic', 0.30511397),
#  ('boxy', 0.30509806),
#  ('Buddhism', 0.30508667),
#  ('tornado', 0.30495346),
#  ('workout', 0.30486122),
#  ('befitting', 0.30445626),
#  ('motion', 0.30445266),
#  ('artistry', 0.30435526),
#  ('work', 0.30434203),
#  ('duopoly', 0.3042699),
#  ('headlong', 0.3041644),
#  ('pegging', 0.30413),
#  ('falter', 0.30411786),
#  ('halo', 0.30408496),
#  ('bookie', 0.30400842),
#  ('scoreboard', 0.3038984),
#  ('Germany', 0.30386752),
#  ('managerial', 0.3038612),
#  ('coachmen', 0.30384356),
#  ('pedestrian', 0.30372378),
#  ('gymnasium', 0.3035873),
#  ('feet', 0.30357486),
#  ('billiard', 0.30355898),
#  ('cable', 0.30352384),
#  ('Uruguay', 0.30350888),
#  ('transferee', 0.30336922),
#  ('boy', 0.30318612),
#  ('folk', 0.30303216),
#  ('flexure', 0.30271173),
#  ('meat', 0.30270115),
#  ('housework', 0.30235162),
#  ('railway', 0.30234814),
#  ('telegraph', 0.30228713),
#  ('histology', 0.30226928),
#  ('scrimmage', 0.30220738),
#  ('espionage', 0.30220604),
#  ('fun', 0.30220115),
#  ('bourn', 0.30218476),
#  ('hangover', 0.30215704),
#  ('schoolmate', 0.30213562),
#  ('hall', 0.3020913),
#  ('carport', 0.30209023),
#  ('childrearing', 0.302088),
#  ('chivalry', 0.30206954),
#  ('foxtrot', 0.302051),
#  ('money', 0.30196574),
#  ('famous', 0.30194762),
#  ('festival', 0.30186397),
#  ('weld', 0.30186248),
#  ('suspension', 0.30176702),
#  ('assault', 0.30174452),
#  ('box', 0.30162987),
#  ('rickety', 0.3015356),
#  ('forgetting', 0.30148637),
#  ('amongst', 0.3014679),
#  ('sericulture', 0.30131823),
#  ('felony', 0.30131686),
#  ('garland', 0.30124906),
#  ('legging', 0.30123448),
#  ('bloodbath', 0.30110806),
#  ('ballad', 0.30102313),
#  ('sabbatical', 0.30088258),
#  ('hardware', 0.3008647),
#  ('osteology', 0.3008051),
#  ('skulk', 0.3007982),
#  ('cheese', 0.30075803),
#  ('viola', 0.300739),
#  ('Yale', 0.30072612),
#  ('underclassman', 0.3007205),
#  ('enthusiasm', 0.30071157),
#  ('scuba', 0.30067027),
#  ('Celtic', 0.30062923),
#  ('sidewalk', 0.30061722),
#  ('parade', 0.30059603),
#  ('ruffle', 0.3005211),
#  ('homage', 0.30031392),
#  ('importation', 0.30025265),
#  ('kickback', 0.3001352),
#  ('vying', 0.30009535),
#  ('zoology', 0.30008334),
#  ('bemadden', 0.29998392),
#  ('lechery', 0.2998345),
#  ('spool', 0.29981107),
#  ('spacetime', 0.29978126),
#  ('bachelor', 0.29969108),
#  ('workhorse', 0.29962748),
#  ('workforce', 0.29961443),
#  ('habit', 0.29958805),
#  ('Barcelona', 0.29952684),
#  ('vernacular', 0.29950497),
#  ('thicket', 0.29948834),
#  ('camp', 0.29940027),
#  ('algebra', 0.29937506),
#  ('collegian', 0.29931608),
#  ('florican', 0.2993108),
#  ('physiotherapist', 0.2992735),
#  ('childbearing', 0.29925096),
#  ('televise', 0.29918456),
#  ('Stanford', 0.2991147),
#  ('fire', 0.29910833),
#  ('hying', 0.29910433),
#  ('acrobatic', 0.2990959),
#  ('picnicking', 0.2990412),
#  ('huddle', 0.2990374),
#  ('windfall', 0.29890335),
#  ('casino', 0.29885915),
#  ('commercial', 0.2988549),
#  ('cow', 0.29876694),
#  ('high', 0.29872358),
#  ('holocaust', 0.29867494),
#  ('skim', 0.29865384),
#  ('broccoli', 0.29864007),
#  ('fiery', 0.2984982),
#  ('snuffle', 0.29842138),
#  ('bramble', 0.29836583),
#  ('abuilding', 0.29834312),
#  ('fain', 0.29829705),
#  ('Agricola', 0.29825383),
#  ('stool', 0.29817072),
#  ('fide', 0.2981553),
#  ('polish', 0.2981264),
#  ('forest', 0.2980886),
#  ('lingo', 0.29804653),
#  ('gait', 0.29803568),
#  ('bandwagon', 0.29799038),
#  ('vehicle', 0.2979887),
#  ('contract', 0.2979794),
#  ('participant', 0.29794702),
#  ('spaghetti', 0.29794252),
#  ('oddball', 0.2978868),
#  ('bestselling', 0.29786187),
#  ('Russia', 0.29774028),
#  ('gypsy', 0.29760045),
#  ('musicology', 0.2975158),
#  ('petroleum', 0.29735613),
#  ('crawl', 0.2973504),
#  ('movie', 0.2973418),
#  ('groundwork', 0.29731286),
#  ('flirtation', 0.2972944),
#  ('sack', 0.29728565),
#  ('suspense', 0.29719394),
#  ('arterial', 0.29719085),
#  ('Ulster', 0.29717597),
#  ('fetal', 0.29712373),
#  ('pediatrician', 0.29698205),
#  ('popular', 0.29695135),
#  ('crochet', 0.29693806),
#  ('bread', 0.29675877),
#  ('ecology', 0.29672128),
#  ('furlough', 0.29668468),
#  ('uniform', 0.2966563),
#  ('adventure', 0.29654133),
#  ('farmhouse', 0.29651922),
#  ('robotics', 0.29649118),
#  ('castle', 0.29647952),
#  ('catechism', 0.2964785),
#  ('cardiology', 0.29645094),
#  ('faery', 0.2964219),
#  ('geography', 0.29636398),
#  ('discipline', 0.2963386),
#  ('pen', 0.29624376),
#  ('scuffle', 0.2961213),
#  ('Rockies', 0.29606742),
#  ('wilderness', 0.2958227),
#  ('clubhouse', 0.29580003),
#  ('spell', 0.29577282),
#  ('bass', 0.29575557),
#  ('thanksgiving', 0.29572585),
#  ('bodyguard', 0.29571342),
#  ('anthropology', 0.29569477),
#  ('life', 0.29560626),
#  ('flotilla', 0.29559442),
#  ('rail', 0.29554904),
#  ('folksinging', 0.29550734),
#  ('Purdue', 0.29540545),
#  ('striptease', 0.29536107),
#  ('FAA', 0.29533207),
#  ('fingertip', 0.29512396),
#  ('jewel', 0.29510278),
#  ('abolition', 0.29507887),
#  ('sockeye', 0.29507512),
#  ('coffin', 0.2949866),
#  ('witch', 0.29494587),
#  ('stroke', 0.29494494),
#  ('locomotion', 0.29493597),
#  ('teleology', 0.29492468),
#  ('schelling', 0.29484028),
#  ('musician', 0.29483193),
#  ('sweat', 0.29482993),
#  ('weed', 0.2946329),
#  ('equestrian', 0.29460174),
#  ('wind', 0.2945976),
#  ('fight', 0.29456195),
#  ('skill', 0.29453284),
#  ('polytechnic', 0.29451603),
#  ('economic', 0.294411),
#  ('sled', 0.2942977),
#  ('slingshot', 0.29428583),
#  ('banish', 0.29419035),
#  ('phone', 0.29413664),
#  ('sputter', 0.29412785),
#  ('A&M', 0.29411504),
#  ('professor', 0.2941056),
#  ('gunplay', 0.29402435),
#  ('medicine', 0.29401395),
#  ('shove', 0.2939182),
#  ('answer', 0.2939182),
#  ('gabble', 0.2938733),
#  ('picket', 0.2938451),
#  ('clockwork', 0.29370597),
#  ('debacle', 0.29357913),
#  ('cornet', 0.29356018),
#  ('steam', 0.29349664),
#  ('reap', 0.29347402),
#  ('footpath', 0.2934484),
#  ('cartwheel', 0.29327956),
#  ('farmland', 0.2932498),
#  ('petrol', 0.29324538),
#  ('luggage', 0.29314697),
#  ('funeral', 0.293079),
#  ('flagrant', 0.2928923),
#  ('musicale', 0.29288256),
#  ('grapple', 0.29287428),
#  ('flute', 0.29286867),
#  ('injury', 0.29283637),
#  ('profuse', 0.29279387),
#  ('catapult', 0.29277712),
#  ('ostracism', 0.2927748),
#  ('gas', 0.2927178),
#  ('board', 0.2927074),
#  ('plugboard', 0.29270488),
#  ('jock', 0.29264927),
#  ('trumpet', 0.2925889),
#  ('breakfast', 0.2925576),
#  ('house', 0.2925051),
#  ('land', 0.29249716),
#  ('marital', 0.29249033),
#  ('wring', 0.29247144),
#  ('influenza', 0.2924298),
#  ('metal', 0.29238653),
#  ('trafficker', 0.2923023),
#  ('hireling', 0.29228592),
#  ('fist', 0.29211065),
#  ('bomb', 0.29200998),
#  ('homebuilding', 0.29196793),
#  ('utmost', 0.29196298),
#  ('haulage', 0.2919258),
#  ('metabolism', 0.29180035),
#  ('larceny', 0.29169694),
#  ('architectural', 0.29165205),
#  ('highboy', 0.29164827),
#  ('SUNY', 0.29152822),
#  ('Spaulding', 0.29152647),
#  ('fingerling', 0.29141146),
#  ('study', 0.2914101),
#  ('advocacy', 0.2913345),
#  ('Madrid', 0.2912389),
#  ('perjury', 0.29120576),
#  ('follicle', 0.29115492),
#  ('sweatshirt', 0.29113424),
#  ('griddle', 0.29107463),
#  ('barefoot', 0.29107088),
#  ('brigand', 0.29106098),
#  ('metallurgy', 0.29095817),
#  ('elementary', 0.29090843),
#  ('drank', 0.29088873),
#  ('tibia', 0.2908576),
#  ('parkway', 0.2907881),
#  ('pageantry', 0.2907114),
#  ('foreign', 0.29065144),
#  ('literate', 0.29065117),
#  ('love', 0.29059714),
#  ('oratorio', 0.29057908),
#  ('UT', 0.2905148),
#  ('cup', 0.2905121),
#  ('siege', 0.29049665),
#  ('toilsome', 0.29048595),
#  ('suspend', 0.29048178),
#  ('territorial', 0.29045397),
#  ('journalese', 0.2904526),
#  ('piddle', 0.2903845),
#  ('exoskeleton', 0.2902729),
#  ('FCC', 0.29023862),
#  ('bus', 0.29019922),
#  ('flatiron', 0.29015198),
#  ('catch', 0.29012448),
#  ('exploitation', 0.29010108),
#  ('jeopardy', 0.2900788),
#  ('confer', 0.28996995),
#  ('comedian', 0.28994316),
#  ('probate', 0.28992155),
#  ('pharmacy', 0.2899099),
#  ('Pitt', 0.28990728),
#  ('pasture', 0.28982818),
#  ('fugal', 0.2897974),
#  ('burbank', 0.28978938),
#  ('architecture', 0.28977436),
#  ('Yankee', 0.28975627),
#  ('thieving', 0.28969374),
#  ('weapon', 0.28959364),
#  ('innuendo', 0.28958794),
#  ('fall', 0.28949174),
#  ('fascicle', 0.28948352),
#  ('astronomy', 0.2894254),
#  ('fence', 0.2894041),
#  ('home', 0.2893402),
#  ('lunchtime', 0.28933564),
#  ('weal', 0.28932592),
#  ('rigging', 0.2892838),
#  ('NYU', 0.28908896),
#  ('pot', 0.28901476),
#  ('dad', 0.28891623),
#  ('squadron', 0.28888965),
#  ('polio', 0.28886896),
#  ('punk', 0.28885043),
#  ('sparling', 0.28884274),
#  ('freemen', 0.28875917),
#  ('whatre', 0.28868213),
#  ('barbell', 0.28862408),
#  ('lugging', 0.28860018),
#  ('brain', 0.2885792),
#  ('pharmacist', 0.28857788),
#  ('studious', 0.28848088),
#  ('deferring', 0.28848058),
#  ('candlestick', 0.2883758),
#  ('Tehran', 0.288363),
#  ('sword', 0.28832665),
#  ('pudding', 0.28828996),
#  ('Brazilian', 0.28823385),
#  ('pulmonary', 0.2882324),
#  ('befuddle', 0.2882106),
#  ('habitual', 0.28815967),
#  ...]

# %% [markdown]
# ### Now fine-tune the model:

# %% [markdown]
# We can notice that these two words have unusually high/low similarity score:

# %%
stadium_emb=model.encode('stadium')
ballet_emb=model.encode('ballet')

print(sklearn.metrics.pairwise.cosine_similarity([encode_football,stadium_emb])[0,1])
print(sklearn.metrics.pairwise.cosine_similarity([encode_football,ballet_emb])[0,1])
# Out:
# 0.4538225
# 0.5431351

# %% [markdown]
# So let's fine tune the model to increase the similarity of stadium and decrease that of ballet:

# %%
from torch.utils.data import DataLoader
from sentence_transformers import  InputExample, losses

# %%
# Fine-tune the model: Adjust embeddings for specific words to modify their similarity scores
#Define the model. Either from scratch of by loading a pre-trained model
model = SentenceTransformer('all-distilroberta-v1')

#Define your train examples. You need more than just two examples...
train_examples = [InputExample(texts=['football', 'ballet'], label=0.1),
    InputExample(texts=['football', 'stadium'], label=0.7)]

#Define your train dataset, the dataloader and the train loss
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)
train_loss = losses.CosineSimilarityLoss(model)

# Fine-tune the model with the specified training objectives
model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=10, warmup_steps=100)
# Out:
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# After fine-tuning, check the new similarity scores between 'football' and 'stadium'/'ballet':

# %%
stadium_emb=model.encode('stadium')
ballet_emb=model.encode('ballet')

print(sklearn.metrics.pairwise.cosine_similarity([uni_encode,stadium_emb])[0,1])
print(sklearn.metrics.pairwise.cosine_similarity([uni_encode,ballet_emb])[0,1])
# Out:
# 0.48246533
# 0.45706216

# %% [markdown]
# ## Sentiment analysis in finance
# First version: <i>29th March 2023</i>

# %% [markdown]
# FinBERT is a pretrained model on several financial NLP tasks, all outperforming traditional machine learning models, deep learning models, and fine-tuned BERT models.
#
# All the fine-tuned FinBERT models are publicly hosted at Huggingface 🤗. Here we will look at two specific instances:
# - **FinBERT-Sentiment**: for sentiment classification task
# - **FinBERT-FLS**: for forward-looking statement (FLS) classification task

# %% [markdown]
# ## Import the transformers:

# %% [markdown]
# First import the pre-trained model:

# %%
from transformers import BertTokenizer, BertForSequenceClassification, pipeline
# Out:
# 2023-03-29 14:59:58.620296: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# tested in transformers==4.18.0 
import transformers
transformers.__version__
# Out:
# '4.26.1'

# %% [markdown]
# ## Sentiment Analysis
# Analyzing financial text sentiment is valuable as it can engage the views and opinions of managers, information intermediaries and investors. FinBERT-Sentiment is a FinBERT model fine-tuned on 10,000 manually annotated sentences from analyst reports of S&P 500 firms.
#
# **Input**: A financial text.
#
# **Output**: Positive, Neutral or Negative.

# %% [markdown]
# Import FinBERT:

# %%
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

# %% [markdown]
# And let's see a small demo:

# %%
# Demonstrate FinBERT's ability to classify financial texts into Positive, Neutral, or Negative sentiments
nlp = pipeline("text-classification", model=finbert, tokenizer=tokenizer)
results = nlp(['growth is strong and we have plenty of liquidity.', 
               'there is a shortage of capital, and we need extra financing.',
              'formulation patents might protect Vasotec to a limited extent.'])

# %%
results
# Out:
# [{'label': 'Positive', 'score': 1.0},
#  {'label': 'Negative', 'score': 0.9952379465103149},
#  {'label': 'Neutral', 'score': 0.9979718327522278}]

# %% [markdown]
# For the rest of the homework:
#
# 1. Download and import the sentiment_analysis dataset.
# 2. Using FinBERT compute the label for each entry of the dataset.
# 3. Compute the f1 score using as y_true the label which come with dataset and as y_pred the predictions from FinBERT.

# %% [markdown]
# ## Import dataset:

# %% [markdown]
# Let's import pandas to manage our dataset as well as the f1 score from sklearn

# %%
import pandas as pd
from sklearn.metrics import f1_score

# %% [markdown]
# To run the lines below, you should replace "dataset_dir" with the name of the folder you have downloaded the dataset in and "dataset_file" with the name of the file (default is sentiment_analysis.txt).

# %%
dataset_dir = 'NLP_finance/'
dataset_file = 'sentiment_analysis.txt'
finance_df = pd.read_csv(dataset_dir+dataset_file,
                     sep='\@',
                     header=None,
                     names=['sentence','label'])
# Out:
# /var/folders/s6/nkp8nbqs76d0sj38044sg1n40000gn/T/ipykernel_58724/2985077442.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   finance_df = pd.read_csv(dataset_dir+dataset_file,

# %% [markdown]
# The dataset is now imported as panda dataframe which is an extremely handy format!

# %%
finance_df
# Out:
#                                                sentence     label
# 0     According to Gran , the company has no plans t...   neutral
# 1     With the new production plant the company woul...  positive
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     In the third quarter of 2010 , net sales incre...  positive
# 4     Operating profit rose to EUR 13.1 mn from EUR ...  positive
# ...                                                 ...       ...
# 3448  Operating result for the 12-month period decre...  negative
# 3449  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 3450  LONDON MarketWatch -- Share prices ended lower...  negative
# 3451  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 3452  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [3453 rows x 2 columns]

# %% [markdown]
# Compute now the prediction:

# %%
nlp = pipeline("text-classification", model=finbert, tokenizer=tokenizer)
results = nlp(finance_df['sentence'].tolist())
y_pred = [item['label'].lower() for item in results]

# %% [markdown]
# Now let's also import the list of lables as well as the true values from the dataset:

# %%
labels = list(set(finance_df['label'].tolist()))
y_true = finance_df['label'].tolist()

# %% [markdown]
# And finally compute the f1 score:

# %%
f1_score(y_true, y_pred,labels=labels,average='macro')
# Out:
# 0.8473605746028382

# %% [markdown]
# 85 % it is pretty remarkable!

# %% [markdown]
# ## FLS-Classification
# Forward-looking statements (FLS) inform investors of managers’ beliefs and opinions about firm's future events or results. Identifying forward-looking statements from corporate reports can assist investors in financial analysis. FinBERT-FLS is a FinBERT model fine-tuned on 3,500 manually annotated sentences from Management Discussion and Analysis section of annual reports of Russell 3000 firms.
#
# **Input**: A financial text.
#
# **Output**: Specific-FLS , Non-specific FLS, or Not-FLS.

# %%
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-fls',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-fls')

# %%
nlp = pipeline("text-classification", model=finbert, tokenizer=tokenizer)
results = nlp(['we expect the age of our fleet to enhance availability and reliability due to reduced downtime for repairs.',
               'on an equivalent unit of production basis, general and administrative expenses declined 24 percent from 1994 to $.67 per boe.',
               'we will continue to assess the need for a valuation allowance against deferred tax assets considering all available evidence obtained in future reporting periods.'])

# %%
results
# Out:
# [{'label': 'Specific FLS', 'score': 0.77278733253479},
#  {'label': 'Not FLS', 'score': 0.9905241131782532},
#  {'label': 'Non-specific FLS', 'score': 0.975904107093811}]
